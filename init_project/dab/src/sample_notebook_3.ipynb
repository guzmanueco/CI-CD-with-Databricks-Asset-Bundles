# %% [markdown]
# # Default notebook
#
# This default notebook is executed using a Lakeflow job as defined in resources/sample_job.job.yml.

# %%
notebook_param = dbutils.widgets.get("from_t2")

# %%
print(notebook_param)

# %%
job_param = notebook_param + " -  passed to next job"

# %%
dbutils.jobs.taskValues.set(key="job_param", value=job_param,)
